# %% [markdown]
# # Optional Lab - Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# In this lab, you will explore an example of multi-class classification using neural networks.
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width500px;height:200px;">
# </figure>

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)
# Out:
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# !pip install pipreqsnb
# Out:
# Collecting pipreqsnb
#   Downloading pipreqsnb-0.2.4.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pipreqs
#   Downloading pipreqs-0.4.13-py2.py3-none-any.whl (33 kB)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from yarg->pipreqs->pipreqsnb) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->yarg->pipreqs->pipreqsnb) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->yarg->pipreqs->pipreqsnb) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->yarg->pipreqs->pipreqsnb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->yarg->pipreqs->pipreqsnb) (1.25.9)
# Building wheels for collected packages: pipreqsnb, docopt
#   Building wheel for pipreqsnb (setup.py) ... done
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4137 sha256=55d59c97c6bb567792fbb61b5114f16f2c20fd6628a7b68f39a6ef8e85b096e0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/23/7f/59/7a87faea552278c8ef0c171ea4d27494eb91ac9380567239b6
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=5180a81a88d86c20d78ddfe9a5878773e494cdb887982f9023c511579abf08f0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built pipreqsnb docopt
# Installing collected packages: docopt, yarg, pipreqs, pipreqsnb
# Successfully installed docopt-0.6.2 pipreqs-0.4.13 pipreqsnb-0.2.4 yarg-0.1.9
# WARNING: You are using pip version 22.0.2; however, version 23.2.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pipreqsnb
# Out:
# pipreqs  /home/jovyan/work
# INFO: Successfully saved requirements file in /home/jovyan/work/requirements.txt

# %%
# !ls
# Out:
# archive			   C2_W2_SoftMax.ipynb	    lab_utils_multiclass_TF.py
# autils.py		   deeplearning.mplstyle    lab_utils_relu.py
# betaversion		   images		    lab_utils_softmax.py
# C2_W2_Multiclass_TF.ipynb  lab_utils_common.py	    __pycache__
# C2_W2_Relu.ipynb	   lab_utils_multiclass.py  requirements.txt

# %%
# !cat requirements.txt
# Out:
# ipython==7.14.0
# ipywidgets==7.5.1
# matplotlib==3.3.2
# numpy==1.21.6
# scikit_learn==0.22.2.post1
# tensorflow==2.8.0

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5222
# Epoch 2/200
# 4/4 [==============================] - 0s 875us/step - loss: 1.4053
# Epoch 3/200
# 4/4 [==============================] - 0s 949us/step - loss: 1.3238
# Epoch 4/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2513
# Epoch 5/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1975
# Epoch 6/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1514
# Epoch 7/200
# 4/4 [==============================] - 0s 944us/step - loss: 1.1119
# Epoch 8/200
# 4/4 [==============================] - 0s 993us/step - loss: 1.0719
# Epoch 9/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0344
# Epoch 10/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9918
# Epoch 11/200
# 4/4 [==============================] - 0s 952us/step - loss: 0.9545
# Epoch 12/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9165
# Epoch 13/200
# 4/4 [==============================] - 0s 986us/step - loss: 0.8815
# Epoch 14/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8454
# Epoch 15/200
# 4/4 [==============================] - 0s 970us/step - loss: 0.8129
# Epoch 16/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7838
# Epoch 17/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7579
# Epoch 18/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7336
# Epoch 19/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7120
# Epoch 20/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6917
# Epoch 21/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6728
# Epoch 22/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6561
# Epoch 23/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6402
# Epoch 24/200
# 4/4 [==============================] - 0s 899us/step - loss: 0.6257
# Epoch 25/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6113
# Epoch 26/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5979
# Epoch 27/200
# 4/4 [==============================] - 0s 849us/step - loss: 0.5864
# Epoch 28/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5745
# Epoch 29/200
# 4/4 [==============================] - 0s 969us/step - loss: 0.5627
# Epoch 30/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5508
# Epoch 31/200
# 4/4 [==============================] - 0s 978us/step - loss: 0.5397
# Epoch 32/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5292
# Epoch 33/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5189
# Epoch 34/200
# 4/4 [==============================] - 0s 918us/step - loss: 0.5102
# Epoch 35/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5008
# Epoch 36/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4924
# Epoch 37/200
# 4/4 [==============================] - 0s 882us/step - loss: 0.4837
# Epoch 38/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4757
# Epoch 39/200
# 4/4 [==============================] - 0s 949us/step - loss: 0.4684
# Epoch 40/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4615
# Epoch 41/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4548
# Epoch 42/200
# 4/4 [==============================] - 0s 959us/step - loss: 0.4486
# Epoch 43/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4427
# Epoch 44/200
# 4/4 [==============================] - 0s 885us/step - loss: 0.4366
# Epoch 45/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4306
# Epoch 46/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4261
# Epoch 47/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4204
# Epoch 48/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4148
# Epoch 49/200
# 4/4 [==============================] - 0s 814us/step - loss: 0.4089
# Epoch 50/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4043
# Epoch 51/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3997
# Epoch 52/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3950
# Epoch 53/200
# 4/4 [==============================] - 0s 965us/step - loss: 0.3912
# Epoch 54/200
# 4/4 [==============================] - 0s 945us/step - loss: 0.3854
# Epoch 55/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3795
# Epoch 56/200
# 4/4 [==============================] - 0s 931us/step - loss: 0.3730
# Epoch 57/200
# 4/4 [==============================] - 0s 980us/step - loss: 0.3675
# Epoch 58/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3615
# Epoch 59/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3555
# Epoch 60/200
# 4/4 [==============================] - 0s 996us/step - loss: 0.3470
# Epoch 61/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3387
# Epoch 62/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3305
# Epoch 63/200
# 4/4 [==============================] - 0s 944us/step - loss: 0.3222
# Epoch 64/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3138
# Epoch 65/200
# 4/4 [==============================] - 0s 985us/step - loss: 0.3072
# Epoch 66/200
# 4/4 [==============================] - 0s 924us/step - loss: 0.3006
# Epoch 67/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2945
# Epoch 68/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2885
# Epoch 69/200
# 4/4 [==============================] - 0s 999us/step - loss: 0.2828
# Epoch 70/200
# 4/4 [==============================] - 0s 863us/step - loss: 0.2766
# Epoch 71/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2708
# Epoch 72/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2661
# Epoch 73/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2615
# Epoch 74/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2571
# Epoch 75/200
# 4/4 [==============================] - 0s 957us/step - loss: 0.2527
# Epoch 76/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2474
# Epoch 77/200
# 4/4 [==============================] - 0s 837us/step - loss: 0.2428
# Epoch 78/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2375
# Epoch 79/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2332
# Epoch 80/200
# 4/4 [==============================] - 0s 828us/step - loss: 0.2294
# Epoch 81/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2258
# Epoch 82/200
# 4/4 [==============================] - 0s 925us/step - loss: 0.2220
# Epoch 83/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2184
# Epoch 84/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2148
# Epoch 85/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2112
# Epoch 86/200
# 4/4 [==============================] - 0s 991us/step - loss: 0.2081
# Epoch 87/200
# 4/4 [==============================] - 0s 895us/step - loss: 0.2050
# Epoch 88/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2015
# Epoch 89/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1980
# Epoch 90/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1944
# Epoch 91/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1901
# Epoch 92/200
# 4/4 [==============================] - 0s 976us/step - loss: 0.1871
# Epoch 93/200
# 4/4 [==============================] - 0s 966us/step - loss: 0.1837
# Epoch 94/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1803
# Epoch 95/200
# 4/4 [==============================] - 0s 896us/step - loss: 0.1770
# Epoch 96/200
# 4/4 [==============================] - 0s 952us/step - loss: 0.1743
# Epoch 97/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1721
# Epoch 98/200
# 4/4 [==============================] - 0s 952us/step - loss: 0.1693
# Epoch 99/200
# 4/4 [==============================] - 0s 964us/step - loss: 0.1678
# Epoch 100/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1656
# Epoch 101/200
# 4/4 [==============================] - 0s 980us/step - loss: 0.1648
# Epoch 102/200
# 4/4 [==============================] - 0s 935us/step - loss: 0.1628
# Epoch 103/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0620
# Epoch 171/200
# 4/4 [==============================] - 0s 802us/step - loss: 0.0614
# Epoch 172/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0606
# Epoch 173/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0608
# Epoch 174/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0607
# Epoch 175/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0592
# Epoch 176/200
# 4/4 [==============================] - 0s 944us/step - loss: 0.0581
# Epoch 177/200
# 4/4 [==============================] - 0s 847us/step - loss: 0.0581
# Epoch 178/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0573
# Epoch 179/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0590
# Epoch 180/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0582
# Epoch 181/200
# 4/4 [==============================] - 0s 988us/step - loss: 0.0569
# Epoch 182/200
# 4/4 [==============================] - 0s 849us/step - loss: 0.0568
# Epoch 183/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0563
# Epoch 184/200
# 4/4 [==============================] - 0s 850us/step - loss: 0.0550
# Epoch 185/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0533
# Epoch 186/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0525
# Epoch 187/200
# 4/4 [==============================] - 0s 862us/step - loss: 0.0526
# Epoch 188/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0524
# Epoch 189/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0520
# Epoch 190/200
# 4/4 [==============================] - 0s 775us/step - loss: 0.0519
# Epoch 191/200
# 4/4 [==============================] - 0s 945us/step - loss: 0.0519
# Epoch 192/200
# 4/4 [==============================] - 0s 987us/step - loss: 0.0517
# Epoch 193/200
# 4/4 [==============================] - 0s 859us/step - loss: 0.0510
# Epoch 194/200
# 4/4 [==============================] - 0s 931us/step - loss: 0.0503
# Epoch 195/200
# 4/4 [==============================] - 0s 985us/step - loss: 0.0494
# Epoch 196/200
# 4/4 [==============================] - 0s 704us/step - loss: 0.0487
# Epoch 197/200
# 4/4 [==============================] - 0s 788us/step - loss: 0.0481
# Epoch 198/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0476
# Epoch 199/200
# 4/4 [==============================] - 0s 995us/step - loss: 0.0475
# Epoch 200/200
# 4/4 [==============================] - 0s 972us/step - loss: 0.0472

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 434us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
y_train
# Out:
# array([3, 3, 3, 0, 3, 3, 3, 3, 2, 0, 2, 1, 1, 1, 0, 3, 2, 3, 1, 2, 3, 0,
#        1, 2, 2, 0, 3, 1, 0, 0, 3, 0, 3, 2, 3, 1, 1, 2, 3, 0, 0, 2, 3, 0,
#        3, 1, 1, 3, 3, 0, 0, 2, 0, 2, 2, 0, 0, 3, 3, 2, 0, 0, 0, 1, 2, 1,
#        1, 1, 3, 1, 1, 2, 3, 0, 1, 2, 2, 0, 1, 1, 2, 2, 2, 1, 1, 0, 1, 0,
#        2, 3, 3, 0, 2, 1, 2, 1, 1, 2, 2, 0])

# %%
y_train.reshape(-1,)
# Out:
# array([3, 3, 3, 0, 3, 3, 3, 3, 2, 0, 2, 1, 1, 1, 0, 3, 2, 3, 1, 2, 3, 0,
#        1, 2, 2, 0, 3, 1, 0, 0, 3, 0, 3, 2, 3, 1, 1, 2, 3, 0, 0, 2, 3, 0,
#        3, 1, 1, 3, 3, 0, 0, 2, 0, 2, 2, 0, 0, 3, 3, 2, 0, 0, 0, 1, 2, 1,
#        1, 1, 3, 1, 1, 2, 3, 0, 1, 2, 2, 0, 1, 1, 2, 2, 2, 1, 1, 0, 1, 0,
#        2, 3, 3, 0, 2, 1, 2, 1, 1, 2, 2, 0])

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes) #same as y_train
# Out:
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /Volumes/Transcend/programming Study/ML and DL jupyter notebook/Course 2 Wk2 Labs/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1 <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.

# %% [markdown]
# ## Congratulations!
# You have learned to build and operate a neural network for multiclass classification.
